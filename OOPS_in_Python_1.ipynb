# %% [markdown]
# ### *Object Oriented Programming (OOP)*

# %% [markdown]
# ##### Object-Oriented Programming (OOP) is a programming paradigm that organizes software design around data, or objects, rather than functions and logic.

# %% [markdown]
# ### Class

# %%
# In object-oriented programming (OOP), a class is a blueprint for creating objects that share common properties and behaviours.
# A class defines the structure (attributes) and behaviour (methods) of objects. It acts as a template from which
# individual instances (objects) are created.

# %%
# In Python, data types are implemented as classes. This is a key feature of Python’s object-oriented nature.
# Every value in Python is an object, and its type is defined by a class. For example:
# - int is a class for integer objects.
# - str is a class for string objects.
# - list is a class for list objects.
# - dict is a class for dictionary objects.

# %%
# Think of a class like a recipe:
# - Ingredients = data (attributes)
# - Steps = functions (methods)
# - Dish = object (instance of the class)

# %%
x = 5
print(type(x))  

y = "hello"
print(type(y))  

L=[1,2,3]  #  L is an object of class 'list'
print(type(L))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'list'>

# %% [markdown]
# ### Object

# %%
# An object is an instance of a class that contains both data (attributes) and behaviour (methods).
# Everything in Python—whether it's a number, string, list, or even a function—is treated as an object

# %% [markdown]
# #### Syntax to create an object

# %%
# objectname = classname()

L=list()
print(L)

s=str()
print(s)
# Out:
# []

# %%
# Banking Application

# %%
class Atm:
    def __init__(self):
        self.pin = ""
        self.balance = 0
        self.menu()

    def menu(self):
        while True:
            user_input = input("""
            1. Press 1 to create a pin
            2. Press 2 to change pin
            3. Press 3 to check balance
            4. Press 4 to withdraw
            5. Anything else to exit
            """)

            if user_input == "1":
                self.create_pin()
            elif user_input == "2":
                self.change_pin()
            elif user_input == "3":
                self.check_balance()
            elif user_input == "4":
                self.withdraw()
            else:
                print("Exiting...")
                break

    def create_pin(self):
        self.pin = input("Enter your new PIN: ")
        self.balance = int(input("Enter initial balance: "))
        print("PIN created successfully!")

    def change_pin(self):
        old_pin = input("Enter your current PIN: ")
        if old_pin == self.pin:
            self.pin = input("Enter your new PIN: ")
            print("PIN changed successfully!")
        else:
            print("Incorrect PIN!")

    def check_balance(self):
        entered_pin = input("Enter your PIN: ")
        if entered_pin == self.pin:
            print(f"Your balance is: ₹{self.balance}")
        else:
            print("Incorrect PIN!")

    def withdraw(self):
        entered_pin = input("Enter your PIN: ")
        if entered_pin == self.pin:
            amount = int(input("Enter amount to withdraw: "))
            if amount <= self.balance:
                self.balance -= amount
                print(f"Withdrawal successful! Remaining balance: ₹{self.balance}")
            else:
                print("Insufficient balance!")
        else:
            print("Incorrect PIN!")

# Create the ATM object
atm = Atm()
# Out:
#             1. Press 1 to create a pin
#             2. Press 2 to change pin
#             3. Press 3 to check balance
#             4. Press 4 to withdraw
#             5. Anything else to exit
#              1
# Enter your new PIN:  1234
# Enter initial balance:  100000
# PIN created successfully!
#             1. Press 1 to create a pin
#             2. Press 2 to change pin
#             3. Press 3 to check balance
#             4. Press 4 to withdraw
#             5. Anything else to exit
#              2
# Enter your current PIN:  1234
# Enter your new PIN:  9876
# PIN changed successfully!
#             1. Press 1 to create a pin
#             2. Press 2 to change pin
#             3. Press 3 to check balance
#             4. Press 4 to withdraw
#             5. Anything else to exit
#              3
# Enter your PIN:  9876
# Your balance is: ₹100000
#             1. Press 1 to create a pin
#             2. Press 2 to change pin
#             3. Press 3 to check balance
# ...

# %% [markdown]
# ### Method

# %%
# A method is a function defined inside a class and is used to manipulate or interact with the data of that class.
# The key difference between a method and a function is that methods operate on objects and often use the self parameter,
# while functions are independent blocks of code outside the class

# %%
L=[1,2,3]
len(L) #function-->because it is outside the class
L.append() #method-->because it is inside the class

# %% [markdown]
# ### Magic Methods/Dunder Methods in Python

# %%
# Magic methods are special methods in Python that start and end with double underscores (__).
# They enable custom behaviour for built-in operations like addition, printing, length, etc.
# Ex = methods like __init__, __str__, __len__, etc.

# %% [markdown]
# #### Constructor

# %%
# A constructor in Python is a special method used to initialise a newly created object from a class.
# It sets up the object with its initial state — like assigning values to its attributes.
""" A constructor is used to write configuration-related code, such as connecting to the internet or fetching data,
especially in cases where we want these operations to happen automatically and not be exposed to user control"""
# Out:
# ' A constructor is used to write configuration-related code, such as connecting to the internet or fetching data,\nespecially in cases where we want these operations to happen automatically and not be exposed to user control'

# %% [markdown]
# #### __ init __ method

# %%
#  __init__ is called the constructor in Python. It’s a special method that runs automatically when you create a new object from a class.
# It initialises the object’s attributes with the values you provide.

# %%
class WeatherFetcher:
    def __init__(self, city):
        self.city = city
        self.data = self._fetch_weather()

    def _fetch_weather(self):
        # Simulated API call
        print(f"Fetching weather for {self.city}...")
        return {"temp": 25, "condition": "Sunny"}

w = WeatherFetcher("Pune")
print(w.data)
# Out:
# Fetching weather for Pune...
# {'temp': 25, 'condition': 'Sunny'}

# %% [markdown]
# #### Self

# %%
# It represents the instance of the class being used. Whenever we create an object from a class, self refers to the current object instance.
# It is essential for accessing attributes and methods within the class.

# %%
class Check:
    def __init__(self):
        print("Address of self = ", id(self))

obj = Check()
print("Address of class object = ", id(obj))
# Out:
# Address of self =  1953278813792
# Address of class object =  1953278813792

# %% [markdown]
# #### __ str __ method

# %%
# The __str__ method in Python is used to define the human-readable string representation of an object.
# __str__ is a special method that defines what an object looks like when printed

class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

    def __str__(self):
        return f"'{self.title}' by {self.author}"

b = Book("1984", "George Orwell")
print(b)
# Out:
# '1984' by George Orwell

# %% [markdown]
# #### __ add __ method

# %%
# The __add__ method in Python is a special method used to define the behavior of the + operator for objects of a class.
# __add__ lets you customize how + works between objects of your class.

# %% [markdown]
# #### __ sub__ method

# %%
# The __sub__ method in Python is a special method used to define the behaviour of the - (subtraction) operator for objects of a class.

# %% [markdown]
# #### __ mul __ method

# %%
# The __mul__ method in Python is a special method used to define the behaviour of the * (multiplication) operator for objects of a class.

# %% [markdown]
# #### __ truediv __ method

# %%
# The __truediv__ method in Python is a special method that defines the behavior of the / (true division) operator for objects of a class.

# %% [markdown]
# #### Fraction Class

# %%
# Create your own fraction class data type

class Fraction:
    # parameterised constructor
    def __init__(self,x,y):
        self.num=x
        self.den=y
        
    def __str__(self):
        return '{}/{}'.format(self.num,self.den)

    def __add__(self,other):
        new_num=self.num*other.den + other.num*self.den
        new_den=self.den*other.den
        return '{}/{}'.format(new_num,new_den)

    def __sub__(self,other):
        new_num=self.num*other.den - other.num*self.den
        new_den=self.den*other.den
        return '{}/{}'.format(new_num,new_den)

    def __mul__(self,other):
        new_num=self.num*other.num
        new_den=self.den*other.den
        return '{}/{}'.format(new_num,new_den)

    def __truediv__(self,other):
        new_num=self.num*other.den
        new_den=self.den*other.num
        return '{}/{}'.format(new_num,new_den)

    #non-magic method
    # Non-magic methods are regular methods you define in a class to perform specific tasks.
    # They don’t have double underscores (__) around their names.
    
    def convert_to_decimal(self):
        return self.num/self.den
        
        
frac1=Fraction(3,4)
frac2=Fraction(1,5)
print(frac1)
print(frac2)
print(frac1+frac2)
print(frac1-frac2)
print(frac1*frac2)
print(frac1/frac2)
print(frac1.convert_to_decimal())
# Out:
# 3/4
# 1/5
# 19/20
# 11/20
# 3/20
# 15/4
# 0.75

# %% [markdown]
#  Write OOP classes to handle the following scenarios:
# * A user can create and view 2D coordinates
# * A user can find out the distance between 2 coordinates
# * A user can find find the distance of a coordinate from origin
# * A user can check if a point lies on a given line
# * A user can find the distance between a given 2D point and a given line

# %%
class Point():
    def __init__(self,x,y):
        self.x_cod=x
        self.y_cod=y

    def __str__(self):
        return '<{},{}>'.format(self.x_cod,self.y_cod)

    def euclidean_distance(self,other):
        return((self.x_cod-other.x_cod)**2 + (self.y_cod-other.y_cod)**2)**0.5

    def distance_from_origin(self):
        return self.euclidean_distance(Point(0,0))

class Line:
    def __init__(self,A,B,C):
        self.A=A
        self.B=B
        self.C=C

    def __str__(self):
        return '{}x + {}y + {} = 0'.format(self.A,self.B,self.C)

    def point_on_line(line,point):
        if line.A*point.x_cod + line.B*point.y_cod + line.C == 0:
            return "lies on the line"
        else:
            return "does not lie on line"

    def shortest_distance(line,point):
        return abs(line.A*point.x_cod + line.B*point.y_cod + line.C) / (line.A**2 + line.B**2)**0.5

# %%
p1=Point(2,1)
p2=Point(1,1)
print(p1)
print(p2)
print(p1.euclidean_distance(p2))
print(p1.distance_from_origin())
# Out:
# <2,1>
# <1,1>
# 1.0
# 2.23606797749979

# %%
l1=Line(1,1,-2)
p1=Point(1,1)
print(l1)
print(p1)
print(l1.point_on_line(p1))
print(l1.shortest_distance(p1))
# Out:
# 1x + 1y + -2 = 0
# <1,1>
# lies on the line
# 0.0

# %% [markdown]
# ### How objects access attributes

# %%
class Person:

  def __init__(self,name_input,country_input):
    self.name = name_input
    self.country = country_input

  def greet(self):
    if self.country == 'India':
      print('Namaste',self.name)
    else:
      print('Hello',self.name)

# %%
# how to access attributes
p = Person('Abhishek','India')

# %%
print(p.name)
# Out:
# Abhishek

# %%
# how to access methods
p.greet()
# Out:
# Namaste Abhishek

# %%
# what if you try to access non-existent attributes
p.gender  #Error

# %% [markdown]
# #### Attribute creation from outside of the class

# %%
#using obj if you want you can make attributes outside the class
p.gender = 'male'

# %%
print(p.gender)
# Out:
# male

# %% [markdown]
# ### Reference Variables
#
# - Reference variables hold the objects
# - We can create objects without reference variable as well
# - An object can have multiple reference variables
# - Assigning a new reference variable to an existing object does not create a new object

# %%
# object without a reference
class Person:

  def __init__(self):
    self.name = 'nitish'
    self.gender = 'male'

p = Person()  # p is not technically the object, but p(reference variable) contains the address of the object
q = p

# %%
# Multiple ref
print(id(p))
print(id(q))
# Out:
# 1953278817152
# 1953278817152

# %%
# change attribute value with the help of 2nd object

# %%
print(p.name)
print(q.name)
q.name='vedant'
print(p.name)
print(q.name)
# Out:
# nitish
# nitish
# vedant
# vedant

# %% [markdown]
# ### Pass by reference

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print('Hi my name is',person.name,'and I am a',person.gender)  # function takes a Person object as input
  p1 = Person('Ankit','Male')
  return p1

p = Person('Nitish','Male')
x = greet(p)  # The greet function prints details of the passed-in object (p), but returns a new object (p1).
print(x.name)
print(x.gender)
# Out:
# Hi my name is Nitish and I am a Male
# Ankit
# Male

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print(id(person))
  person.name = 'Ankit'
  print(person.name)

p = Person('Nitish','Male')
print(id(p))
greet(p)
print(p.name)
# Out:
# 1953278817488
# 1953278817488
# Ankit
# Ankit

# %% [markdown]
# #### Object ki mutability

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  person.name = 'ankit'
  return person

p = Person('nitish','male')
print(id(p))
p1 = greet(p)
print(id(p1))  # obj is mutable hence same memory address
# Out:
# 1953278816144
# 1953278816144

# %%
# instance variable-->An instance variable is a variable defined using self.variable_name inside a class method (typically __init__), 
# and it belongs to a specific object, allowing each instance of the class to store its own unique value.
class Person:
    def __init__(self, name, gender):
        self.name = name        # instance variable
        self.gender = gender    # instance variable

p1 = Person('Ankit', 'Male')
p2 = Person('Riya', 'Female')

print(p1.name)  # Output: Ankit
print(p2.name)  # Output: Riya
# Out:
# Ankit
# Riya

# %% [markdown]
# ### Encapsulation

# %% [markdown]
# ##### Encapsulation is the process of wrapping data (variables) and code (methods) together into a single unit, typically a class,
# ##### and restricting access to some of the object's internal details. This is done to prevent unintended interference and misuse of the data.

# %%
# Example
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance  # private variable(__)
       # Here, __balance is encapsulated — it can’t be accessed directly from outside the class

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount

    def get_balance(self):
        return self.__balance

# %%
class Atm:

  # constructor(special function)->superpower -> 
  def __init__(self):
    print(id(self))
    self.pin = '1234'
    self.__balance = 0
    #self.menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def menu(self):
      while True:
        user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)
          
        if user_input == '1':
          self.create_pin()
        elif user_input == '2':
          self.change_pin()
        elif user_input == '3':
          self.check_balance()
        elif user_input == '4':
          self.withdraw()
        else:
            print("Thank you for using ATM")
            break

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
        amount = int(input('enter the amount'))
        if amount <= self.__balance:
            self.__balance = self.__balance - amount
            print('withdrawl successful.balance is',self.__balance)
        else:
            print('abe garib')
    else:
      print('sale chor')

# %%
obj = Atm()
# Out:
# 1953278818496

# %%
print(obj.menu())
# Out:
#     Hi how can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#      1
# enter your pin 1985
# enter balance 50000
# pin created successfully
#     Hi how can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#      5
# Thank you for using ATM
# None

# %%
obj.__balance == "Changing to new"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 obj.__balance == "Changing to new"
#
# AttributeError: 'Atm' object has no attribute '__balance'

# %%
# Whenever you create a variable(private) like:

# self.__balance

# Python internally renames (mangles) it to:

# self._Atm__balance

# %%
# - self.__balance is a private instance variable (name-mangled with double underscore).
# - Access is controlled via:
# - get_balance() → read-only access
# - set_balance(new_value) → write access with type-checking

# %%
obj.set_balance(1000)

# %%
print(obj.get_balance())
# Out:
# 1000

# %%
print(obj.withdraw())
# Out:
# enter the pin 1985
# enter the amount 12000
# abe garib
# None

# %%
# Note: private variables be accessed without get and set methods?
# Technically, yes — but it's not recommended.
# Python uses a mechanism called name mangling for variables with double underscores (__balance).
# This means the variable is internally renamed to _ClassName__variableName

# %%
# in this case name mangling
atm = Atm()
atm.pin = '1234'
atm._Atm__balance = 5000  # Direct access using name mangling
print(atm._Atm__balance)
# Out:
# 1953292741008
# 5000

# %% [markdown]
# ### Collection of objects

# %%
# list of objects
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = Person('Abhishek','male')
p2 = Person('Ram','male')
p3 = Person('Neha','female')

L = [p1,p2,p3]

for i in L:
  print(i.name,i.gender)
# Out:
# Abhishek male
# Ram male
# Neha female

# %%
# dict of objects
# list of objects
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender
      
p1 = Person('Abhishek','male')
p2 = Person('Ram','male')
p3 = Person('Neha','female')

d = {'p1':p1,'p2':p2,'p3':p3}

for i in d:
  print(d[i].gender)
# Out:
# male
# male
# female

# %% [markdown]
# ### Static Variables( vs Instance variables)

# %%
# need for static variables
# -Instance variables are unique to each object, while static (or class) variables are shared across all instances of a class.

# %%
class Atm:

  __counter = 1

  # constructor(special function)->superpower -> 
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    self.cid = Atm.__counter
    Atm.__counter = Atm.__counter + 1
    #self.menu()

  # utility functions
  @staticmethod
  def get_counter():
    return Atm.__counter


  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
c1 = Atm()
# Out:
# 1953278819504

# %%
c2 = Atm()
# Out:
# 1953292742928

# %%
c3 = Atm()
# Out:
# 1953292744208

# %%
print(c1.cid)
# Out:
# 1

# %%
print(c2.cid)
# Out:
# 2

# %%
print(c3.cid)
# Out:
# 3
